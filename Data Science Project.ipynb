# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
data = pd.read_csv("G:\Practices From Youtube and Online\Edureka\DS Project\Covid 19 Global.csv")

# %%
data.head()
# Out:
#                                      Name  WHO Region  \
# Global                                NaN   273900334
# United States of America         Americas    50415400
# India                     South-East Asia    34746838
# Brazil                           Americas    22204941
# The United Kingdom                 Europe    11361391
#
#                           Cases - cumulative total  \
# Global                                 3514.002384
# United States of America              15231.117000
# India                                  2517.879000
# Brazil                                10446.463000
# The United Kingdom                    16735.984000
#
#                           Cases - cumulative total per 100000 population  \
# Global                                                           4210729
# United States of America                                          827506
# India                                                              48978
# ...

# %%
data.columns
# Out:
# Index(['Name', 'WHO Region', 'Cases - cumulative total',
#        'Cases - cumulative total per 100000 population',
#        'Cases - newly reported in last 7 days',
#        'Cases - newly reported in last 7 days per 100000 population',
#        'Cases - newly reported in last 24 hours', 'Deaths - cumulative total',
#        'Deaths - cumulative total per 100000 population',
#        'Deaths - newly reported in last 7 days',
#        'Deaths - newly reported in last 7 days per 100000 population',
#        'Deaths - newly reported in last 24 hours'],
#       dtype='object')

# %%
data.tail()
# Out:
#                              Name  WHO Region  Cases - cumulative total  \
# Pitcairn Islands  Western Pacific           0                       0.0
# Saint Helena               Africa           0                       0.0
# Tokelau           Western Pacific           0                       0.0
# Turkmenistan               Europe           0                       0.0
# Tuvalu            Western Pacific           0                       0.0
#
#                   Cases - cumulative total per 100000 population  \
# Pitcairn Islands                                               0
# Saint Helena                                                   0
# Tokelau                                                        0
# Turkmenistan                                                   0
# Tuvalu                                                         0
#
#                   Cases - newly reported in last 7 days  \
# Pitcairn Islands                                    0.0
# ...

# %%
data.describe()
# Out:
#          WHO Region  Cases - cumulative total  \
# count  2.380000e+02                237.000000
# mean   2.301683e+06               6256.397048
# std    1.822961e+07               6192.779064
# min    0.000000e+00                  0.000000
# 25%    1.056600e+04                489.366000
# 50%    9.298750e+04               5174.786000
# 75%    5.768982e+05              10269.558000
# max    2.739003e+08              26595.483000
#
#        Cases - cumulative total per 100000 population  \
# count                                    2.380000e+02
# mean                                     3.538428e+04
# std                                      2.816376e+05
# min                                      0.000000e+00
# 25%                                      5.675000e+01
# 50%                                      6.880000e+02
# 75%                                      5.736250e+03
# max                                      4.210729e+06
#
#        Cases - newly reported in last 7 days  \
# ...

# %%
data.isnull()
# Out:
#                            Name  WHO Region  Cases - cumulative total  \
# Global                     True       False                     False
# United States of America  False       False                     False
# India                     False       False                     False
# Brazil                    False       False                     False
# The United Kingdom        False       False                     False
# ...                         ...         ...                       ...
# Pitcairn Islands          False       False                     False
# Saint Helena              False       False                     False
# Tokelau                   False       False                     False
# Turkmenistan              False       False                     False
# Tuvalu                    False       False                     False
#
#                           Cases - cumulative total per 100000 population  \
# ...

# %%
data.isnull().sum()
# Out:
# Name                                                              1
# WHO Region                                                        0
# Cases - cumulative total                                          1
# Cases - cumulative total per 100000 population                    0
# Cases - newly reported in last 7 days                             1
# Cases - newly reported in last 7 days per 100000 population       0
# Cases - newly reported in last 24 hours                           0
# Deaths - cumulative total                                         1
# Deaths - cumulative total per 100000 population                   0
# Deaths - newly reported in last 7 days                            1
# Deaths - newly reported in last 7 days per 100000 population      0
# Deaths - newly reported in last 24 hours                        238
# dtype: int64

# %%
#relating the variables with scatterplots

# %%
data.columns
# Out:
# Index(['Name', 'WHO Region', 'Cases - cumulative total',
#        'Cases - cumulative total per 100000 population',
#        'Cases - newly reported in last 7 days',
#        'Cases - newly reported in last 7 days per 100000 population',
#        'Cases - newly reported in last 24 hours', 'Deaths - cumulative total',
#        'Deaths - cumulative total per 100000 population',
#        'Deaths - newly reported in last 7 days',
#        'Deaths - newly reported in last 7 days per 100000 population',
#        'Deaths - newly reported in last 24 hours'],
#       dtype='object')

# %%
sns.relplot(x="Cases - cumulative total",y="Deaths - cumulative total",hue="WHO Region",data=data)

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['Name', 'WHO Region', 'Cases - cumulative total',
#        'Cases - cumulative total per 100000 population',
#        'Cases - newly reported in last 7 days',
#        'Cases - newly reported in last 7 days per 100000 population',
#        'Cases - newly reported in last 24 hours', 'Deaths - cumulative total',
#        'Deaths - cumulative total per 100000 population',
#        'Deaths - newly reported in last 7 days',
#        'Deaths - newly reported in last 7 days per 100000 population',
#        'Deaths - newly reported in last 24 hours'],
#       dtype='object')

# %%
sns.relplot(x="Cases - cumulative total",y="Deaths - cumulative total",kind="line",data=data)

# %%
sns.catplot(x="Cases - cumulative total",y="Deaths - cumulative total",data=data)
